# %%
import pandas as pd
import numpy as np

customers = {
  "id": [1, 2, 3, 4],
  "name": ["Alice", "Bob", "Charlie", "David"]
}

orders = {
  "id": [1, 2],
  "customer_id": [1, 3]
}

df_customers = pd.DataFrame(customers)
df_orders = pd.DataFrame(orders)

# %%
df_customers
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David

# %%
df_orders
# Out:
#    id  customer_id
# 0   1            1
# 1   2            3

# %%
# Gemini
df_inactive = df_customers.loc[~df_customers["id"].isin(df_orders["customer_id"]), ["name"]]

# Me
# df_inactive = df_customers[~(df_customers["id"].isin(df_orders["customer_id"]))]
# df_inactive.loc[:, ["name"]]

# %%
df_inactive.rename(columns={"name": "inactive_customer"}).sort_values("inactive_customer", ascending=False).reset_index(drop=True)
# Out:
#   inactive_customer
# 0             David
# 1               Bob

# %%
# cara ka fani

# %%
df_customers
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David

# %%
df_orders
# Out:
#    id  customer_id
# 0   1            1
# 1   2            3

# %%
list_orders = list(df_orders["customer_id"])

# %%
list_orders
# Out:
# [1, 3]

# %%
list_not_or = df_customers[~(df_customers["id"].isin(list_orders))].sort_values("name", ascending=False).reset_index(drop = True)

# %%
list_name = list(list_not_or["name"])

# %%
list_name
# Out:
# ['David', 'Bob']

# %%
result = pd.DataFrame({
  "Inactive Customer": list_name
})

# %%
result
# Out:
#   Inactive Customer
# 0             David
# 1               Bob
